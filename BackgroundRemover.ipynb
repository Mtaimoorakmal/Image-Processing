# %% [markdown]
# <a href="https://colab.research.google.com/github/Mtaimoorakmal/Image-Processing/blob/main/BackgroundRemover.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
img = Image.open('/content/dp.jpg')

img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=350x368>

# %%
from rembg import remove

output = remove(img)
output.save("dp12.png")
Image.open("dp12.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=350x368>
